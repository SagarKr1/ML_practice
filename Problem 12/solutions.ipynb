# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
features = data.iloc[:,[0,1]].values
label = data.iloc[:,2].values

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# %%
for i in range(1,101):
    for depth in range(3,11):
        x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.2,random_state=i)
        xgbModel = XGBClassifier(n_estimators=5, max_depth=depth,random_state=2)
        
        xgbModel.fit(x_train,y_train)
        
        trainScore = xgbModel.score(x_train,y_train)
        testScore = xgbModel.score(x_test,y_test)
        
        if testScore > trainScore and testScore >= 0.9:
            print(f"Test {testScore} | Train {trainScore} and rs {i} | depth {depth}")
# Out:
# Test 0.925 | Train 0.915625 and rs 5 | depth 3
# Test 0.9375 | Train 0.9125 and rs 6 | depth 3
# Test 0.9375 | Train 0.934375 and rs 6 | depth 5
# Test 0.9375 | Train 0.915625 and rs 9 | depth 3
# Test 0.9375 | Train 0.93125 and rs 9 | depth 4
# Test 0.9375 | Train 0.921875 and rs 18 | depth 3
# Test 0.925 | Train 0.915625 and rs 21 | depth 3
# Test 0.9625 | Train 0.91875 and rs 24 | depth 3
# Test 0.9375 | Train 0.928125 and rs 24 | depth 4
# Test 0.9375 | Train 0.93125 and rs 24 | depth 5
# Test 0.9375 | Train 0.915625 and rs 25 | depth 3
# Test 0.9375 | Train 0.93125 and rs 25 | depth 4
# Test 0.9375 | Train 0.93125 and rs 25 | depth 5
# Test 0.9375 | Train 0.93125 and rs 25 | depth 6
# Test 0.9375 | Train 0.93125 and rs 25 | depth 7
# Test 0.9375 | Train 0.93125 and rs 25 | depth 8
# Test 0.9375 | Train 0.93125 and rs 25 | depth 9
# Test 0.9375 | Train 0.93125 and rs 25 | depth 10
# Test 0.95 | Train 0.91875 and rs 30 | depth 3
# Test 0.9375 | Train 0.93125 and rs 30 | depth 4
# ...

# %%
# Test 0.95 | Train 0.91875 and rs 30 | depth 3

x_train,x_test,y_train,y_test = train_test_split(features,label,test_size=0.2,random_state=30)
xgbModel = XGBClassifier(n_estimators=5, max_depth=3,random_state=2)
        
xgbModel.fit(x_train,y_train)
        
trainScore = xgbModel.score(x_train,y_train)
testScore = xgbModel.score(x_test,y_test)
        
if testScore > trainScore and testScore >= 0.9:
    print(f"Test {testScore} | Train {trainScore}")
# Out:
# Test 0.95 | Train 0.91875

# %%
predict = xgbModel.predict_proba(np.array([[30,422229]]))
predict
# Out:
# array([[0.23247677, 0.7675232 ]], dtype=float32)
